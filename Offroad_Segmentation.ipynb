# %% [markdown]
# <a href="https://colab.research.google.com/github/sailakshmikarnati1122-lgtm/K-means-implementation/blob/main/Offroad_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision torchaudio
# !pip install matplotlib
# !pip install tqdm

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
# Out:
# GPU Available: True

# %%
# %cd "/content/drive/MyDrive/Offroad_Segmentation/Offroad_Segmentation_Scripts (Unzipped Files)"
# Out:
# /content/drive/MyDrive/Offroad_Segmentation/Offroad_Segmentation_Scripts (Unzipped Files)

# %%
# !ls
# Out:
# ENV_SETUP  test_segmentation.py  train_segmentation.py	visualize.py

# %%
# !ls "/content/drive/MyDrive/Offroad_Segmentation/Offroad_Segmentation_Training_Dataset/train"
# Out:
# Color_Images  Segmentation

# %%
# !python train_segmentation.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Evaluating:  96% 1374/1429 [03:07<00:09,  5.91batch/s]
# Evaluating:  96% 1375/1429 [03:07<00:09,  5.79batch/s]
# Evaluating:  96% 1376/1429 [03:07<00:09,  5.67batch/s]
# Evaluating:  96% 1377/1429 [03:08<00:09,  5.74batch/s]
# Evaluating:  96% 1378/1429 [03:08<00:09,  5.65batch/s]
# Evaluating:  97% 1379/1429 [03:08<00:08,  5.72batch/s]
# Evaluating:  97% 1380/1429 [03:08<00:08,  5.70batch/s]
# Evaluating:  97% 1381/1429 [03:08<00:08,  5.74batch/s]
# Evaluating:  97% 1382/1429 [03:08<00:08,  5.76batch/s]
# Evaluating:  97% 1383/1429 [03:09<00:07,  6.17batch/s]
# Evaluating:  97% 1384/1429 [03:09<00:06,  6.66batch/s]
# Evaluating:  97% 1385/1429 [03:09<00:06,  6.98batch/s]
# Evaluating:  97% 1386/1429 [03:09<00:06,  7.17batch/s]
# Evaluating:  97% 1387/1429 [03:09<00:05,  7.46batch/s]
# Evaluating:  97% 1388/1429 [03:09<00:05,  7.35batch/s]
# Evaluating:  97% 1389/1429 [03:09<00:05,  7.69batch/s]
# ...
